# %% [markdown]
# <a href="https://colab.research.google.com/github/R-Kibet/Generative-AI-/blob/main/Text_2_speach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TEXT 2 SPEECH usning Hagging face**
#
# will be using sona/big-small model

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
#example 1

text = "in life choose the best ass"

pipe = pipeline("text-to-speech", "suno/bark-small")

output = pipe(text)
# Out:
# Device set to use cuda:0
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.

# %%
output
# Out:
# {'audio': array([[ 5.2070402e-04, -6.4432970e-07,  3.3048002e-04, ...,
#           2.2560271e-05,  2.7689646e-05,  3.0985801e-05]], dtype=float32),
#  'sampling_rate': 24000}

# %% [markdown]
# **Listen to Audio**

# %%
from IPython.display import Audio

Audio(output["audio"], rate=output["sampling_rate"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
